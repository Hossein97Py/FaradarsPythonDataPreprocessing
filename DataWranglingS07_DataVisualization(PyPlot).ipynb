# %% [markdown]
# # Plotting and Visualization

# %%
#pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
from numpy.random import randn
import random  
np.random.seed(10)

# %% [markdown]
# # plot

# %%
x = [1, 2, 5, 12]
y = [3, 5, 11, 25]

# %%
plt.plot(x, y)
plt.show()

# %%
plt.plot(x, y,'P')
plt.show()

# %%
plt.plot(x, y,'--P')
plt.grid()
plt.show()

# %%
plt.plot(x, y, color='red', linestyle='dashed', linewidth = 2)
plt.show()

# %%
plt.plot(x, y, label='y=2x+1')
plt.legend()
plt.show()

# %%
plt.plot(x, y)

plt.xlabel('x') 
plt.ylabel('y') 

plt.xlim(1,12) 
plt.ylim(3,25) 
plt.show()

# %%
plt.plot(x, y , marker='p', markersize=15)     # marker : o , x ,X , p, P , h , + ,... 
plt.show()

# %%
plt.plot(x, y, marker='o', markersize=20, markerfacecolor='red')
plt.show()

# %%
plt.plot(x,y, label='Default')
plt.plot(x,y, drawstyle='steps-post', label='steps-post')
plt.legend(loc='best') #determines the location of legends
plt.show()

# %% [markdown]
# رسم دو نمودار در یک پنجره نمایش و مشخص کردن لیبل و لجند

# %%
x = np.arange(0, 2*(np.pi), 0.1)  # 0.1 is the step of numbers
y = np.sin(x) 
plt.plot(x, y)
plt.show()

# %%
np.random.seed(12345) # for fixing the random numbers
plt.plot(np.random.randn(100))
plt.show()

# %% [markdown]
# # subplot

# %%
x = [1, 2, 5, 12]
y = [3, 5, 11, 25]

# %%
plt.plot(x, y)
plt.show()

# %%
z = [-4, -3, -2, -1, 0, 1, 2 , 3, 4] 
w = [16, 9, 4, 1, 0, 1, 4, 9, 16] # w = z ** 2

# %%
plt.plot(z, w)
plt.show()

# %%
plt.subplot(211) # 211: 2 row, 1 columns, draw on 1st row
plt.plot(x, y)

plt.subplot(212) # 211: 2 row, 1 columns, draw on 2nd row
plt.plot(z, w)

plt.show()

# %%
plt.subplot(121) # 1 row, 2 columns
plt.plot(x, y)

plt.subplot(122)
plt.plot(z, w)

plt.show()

# %%
plt.subplot(211)
plt.plot(x, y, label='y=2x+1')
plt.legend()

plt.subplot(212)
plt.plot(z, w, label='y=x^2')
plt.legend()

#plt.savefig('d:/test.png')

# %% [markdown]
# ### subplots (has "s" at the end)

# %%
fig, (ax1, ax2) = plt.subplots(2, 1) 

ax1.plot(x, y)
ax1.set(title='y=2x+1')

ax2.plot(z, w)
ax2.set(title='y=x^2')

plt.show()

# %% [markdown]
# # scatter

# %%
x = [1, 2, 5, 12]
y = [3, 5, 11, 25]

# %%
plt.scatter(x, y)
plt.show()

# %%
plt.scatter(x, y, color= "g", marker= "*", s=200)   
plt.show()

# %%
plt.scatter(x, y, label= "stars")   
plt.legend()
plt.show()

# %%
x = [1, 2, 5, 12]
y = [3, 5, 11, 25]

# %%
f, (ax1, ax2) = plt.subplots(1, 2)                 
ax1.plot(x, y,'p')
ax2.scatter(x, y)
plt.show()

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)  # sharey=True: the vertical axis numbers is the same so we only kept one               
ax1.plot(x, y)
ax2.scatter(x, y)
plt.show()

# %% [markdown]
# # bar

# %%
dars = ['C++', 'Python', 'PHP','Java']
score = [18, 20 , 16, 17]

# %%
plt.bar(dars, score)
plt.show()

# %%
plt.bar(dars, score, color='g', width=0.5)
plt.show()

# %%
plt.bar(dars, score, color = ['b', 'r', 'g', 'y'])
plt.show()

# %%
plt.bar(dars, score, tick_label = ['A', 'B', 'C', 'D'] )
plt.show()

# %%
x = [0, 1, 2, 3, 4]
y = [5, 10, 8, 3, 2]
plt.bar(x, y)
plt.show()

# %%
plt.xticks(x, ['A', 'B', 'C', 'D', 'E'])
plt.bar(x, y, color='Green')

plt.xlabel('Grade')
plt.ylabel('# of student')
plt.show()

# %% [markdown]
# # histogram

# %%
age = [1,1,2,3,3,5,7,8,9,10,10,11,11,13,13,15,16,17,18,18,18,19,20,21,21,23,
       24,24,25,25,25,25,26,26,26,27,27,27,27,27,29,30,30,31,33,34,34,34,35,
       36,36,37,37,38,38,39,40,41,41,42,43,44,45,45,46,47,48,48,49,50,51,52,
       53,54,55,55,56,57,58,60,61,63,64,65,66,68,70,71,72,74,75,77,81,83,84,
       87,89,90,90,91]

# %%
plt.hist(age)  
plt.grid(axis='y') # grid only for y axis
plt.show()

# %% [markdown]
# تو این هیستوگرام به طور دیفالت خودش تشخیص داده ده تا ستون داشته باشه. این میشه بین. میتونیم بین ها رو تغییر بدیم

# %%
plt.hist(age, rwidth=0.95, bins=15)   
plt.show()

# %%
fig, ax = plt.subplots(1, 2)
ax[0].hist(age, bins=25, color='r')
ax[1].hist(age, bins=5)
  
plt.show()

# %%
fig, ax = plt.subplots(2, 2)

ax[0, 0].hist(np.random.randn(100000), color='r')
ax[0, 1].hist(np.random.randn(10000), color='g')
ax[1, 0].hist(np.random.randn(1000), color='b')
ax[1, 1].hist(np.random.randn(100), color='y')

plt.subplots_adjust(wspace=0.8, hspace=0.4) # adjust the space between subplots
plt.show()

# %%
mu = 300 # میانگین     
sigma = 15 # انحراف معیار  
data = mu + sigma * np.random.randn(437) # فرمول توزیع نرمال

fig, ax = plt.subplots()
ax.hist(data, bins=50)
plt.show()

# %%
mu = 300      
sigma = 15    
data = mu + sigma * np.random.randn(437)
fig, ax = plt.subplots()

# so far like the above cell

n, bins, patches = ax.hist(data, bins=50, density=True) # از هیستوگرام سه تا خروجی گرفتیم 
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2)) # this is the red dashed plot
ax.plot(bins, y, '--r')
plt.show()

# %% [markdown]
# # pie

# %%
data = [61, 12, 13, 1, 13]
plt.pie(data)
plt.show()

# %%
data = [61, 12, 13, 1, 13]
labels = ["Asia", "Europe", "Africa", "Oceania", "America" ]

p = plt.pie(data, autopct='%1.0f%%') #autopct='%1.1f%%': show the numbers on the plot

plt.legend(p[0], labels)

plt.title('Nationality')
plt.show()

# %%
#

# %%
labels = ["Chinese", "English", "Hindi", "Spanish", "Russian", "Arabic", "Other" ]
d = [17, 9, 8, 6, 6, 4, 50]

p = plt.pie(d, explode=[0, 0, 0, 0.3, 0, 0.2, 0])

plt.legend(p[0], labels)
plt.show()

# %%
labels = ["Chinese", "English", "Hindi", "Spanish", "Russian", "Arabic", "Other" ]
d = [17, 9, 8, 6, 6, 4, 50]

p = plt.pie(d)

plt.legend(p[0], labels, bbox_to_anchor=(0.9,0.8)) # position of the label 
plt.show()

# %% [markdown]
# # Box Plot

# %%
score = [1, 3, 6, 7, 7, 7, 8, 9, 9, 10, 10, 10, 13, 13, 17, 20]

# %%
plt.boxplot(score)  
plt.grid()
plt.show()

# %% [markdown]
# سه تا دایره داده پرت در نظر گرفته شده اون مستطیله ضلع پایینی چارک اول بقیه دیتا، خط نارنجی میانه یا چارک دوم. اون دو تا خط بالا وپایین هم مینیمم و ماکزیمم داده های ما هستند

# %%
plt.boxplot(score, vert=False)    
plt.grid()
plt.show()

# %%
q1 = np.quantile(score, .25) 
q1
# Out:
# 7.0

# %%
q2 = np.quantile(score, .50)
q2
# Out:
# 9.0

# %%
q3 = np.quantile(score, .75)
q3
# Out:
# 10.75

# %%
iqr = q3 - q1
iqr
# Out:
# 3.75

# %%
lv = q1 - 1.5 * iqr 
lv
# Out:
# 1.375

# %% [markdown]
# first we calculated the iqr (the difference between first and third quartile) then using that we could say that any number smaller than (q1 - 1.5*iqr) or greater than (q3 + 1.5*iqr) is on outlier number.
# داده پرت

# %%
hv = q3 + 1.5 * iqr
hv
# Out:
# 16.375

# %%
#

# %%
score1 = [5, 12, 15, 17, 18, 19, 20]
score2 = [3, 4, 5, 7, 10, 11, 20]
data = np.array(score1),np.array(score2)

plt.boxplot(data)  
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)

f = dict(markerfacecolor='g', marker='s')  

b1 = ax1.boxplot(data, patch_artist=True, labels=['Python', 'Java'], flierprops=f)  
b2 = ax2.boxplot(data, patch_artist=True, labels=['Python', 'Java'], notch=True) 

for b in (b1, b2):
    for p, c in zip(b['boxes'], ['r', 'b']):
        p.set_facecolor(c)

plt.show()
# didnt elaborate so much

# %% [markdown]
# # Plotting with pandas

# %%
d = {'speed': [40, 48, 52, 88], 'lifespan': [70, 1.5, 25, 28]}
df = pd.DataFrame(d, index=['elephant', 'rabbit', 'giraffe', 'horse'])
df
# Out:
#           speed  lifespan
# elephant     40      70.0
# rabbit       48       1.5
# giraffe      52      25.0
# horse        88      28.0

# %%
df.plot.bar(rot=0)
plt.show()

# %%
df.plot.bar(subplots=True, rot=30)
plt.show()

# %%
#

# %%
data = [
        ['men', 155], ['men', 158], ['men', 160], ['men', 161], ['men', 162],
        ['men', 165], ['men', 169], ['men', 170], ['men', 173], ['men', 175],
        ['men', 180], ['men', 185], ['men', 185], ['men', 190],
        ['women', 145], ['women', 150], ['women', 156], ['women', 157], 
        ['women', 158],['women', 150], ['women', 156], ['women', 158],
        ['women', 160], ['women', 161], ['women', 178]
       ]

frame = pd.DataFrame(data, columns = ['gender', 'height'])
frame
# Out:
#    gender  height
# 0     men     155
# 1     men     158
# 2     men     160
# 3     men     161
# 4     men     162
# 5     men     165
# 6     men     169
# 7     men     170
# 8     men     173
# 9     men     175
# 10    men     180
# 11    men     185
# 12    men     185
# 13    men     190
# 14  women     145
# 15  women     150
# 16  women     156
# 17  women     157
# 18  women     158
# 19  women     150
# 20  women     156
# 21  women     158
# 22  women     160
# 23  women     161
# 24  women     178

# %%
frame.boxplot()    
plt.show()

# %%
frame.boxplot(by=['gender'])    
plt.show()

# %%
#

# %%
g = [random.choice(['male', 'female']) for _ in range(50)]
a = [x for x in np.random.randint(20, 70, 50)]

dfage = pd.DataFrame({'gender': g, 'age':a})
dfage.head()
# Out:
#    gender  age
# 0  female   65
# 1    male   52
# 2  female   64
# 3  female   29
# 4    male   23

# %%
dfage.boxplot()    
plt.show()

# %%
dfage.boxplot(by=['gender'])    
plt.show()

# %% [markdown]
# # plot.box

# %%
c = {'boxes': 'Green', 
     'whiskers': 'black', 
     'medians': 'Blue', 
     'caps': 'r'}

dfage.plot.box(color=c)  
plt.show()

# %% [markdown]
# # seaborn

# %%
#!pip install seaborn

# %%
import seaborn as sns

# %%
plt.figure(figsize=(3, 4))  
sns.boxplot(x='gender', y='age', data=dfage)
plt.show()

# %% [markdown]
# ## iris

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# یک دیتاستی هست با پنجاه رکورد. مربوط به ابعاد گلبرگ سه نوع گل، هر کدوم از گلها پنجاه رکورد

# %%
sns.boxplot(y=df["sepal_length"], width=0.2);

# %%
sns.boxplot( x=df["sepal_length"], y=df["species"] );

# %%
sns.boxplot( x=df["species"], y=df["sepal_length"]);  # , palette="Blues" ,deep

# %%
sns.set_style("dark")  # dark , whitegrid
sns.boxplot(y=df["sepal_length"], width=0.2);

# %%
sns.violinplot(x=df["species"], y=df["sepal_length"]);
